# %% [markdown]
# # Synopsis
# Add vector space model to database

# %% [markdown]
# # Configuration

# %%
db_name = 'sitcoms.db'
OHCO = ['show_num', 'seas_num', 'epis_num', 'sent_num', 'token_num']

# %% [markdown]
# # Libraries

# %%
import sqlite3
import pandas as pd
import numpy as np

# %% [markdown]
# # Process

# %%
with sqlite3.connect(db_name) as db:
    K = pd.read_sql('SELECT * FROM token', db, index_col=OHCO)
    V = pd.read_sql('SELECT * FROM vocab', db, index_col='term_id')

# %% [markdown]
# ## Create DTM

# %% [markdown]
# ### Create word mask
#
# Filter out stopwords and proper nouns

# %%
WORDS = (K.punc == 0) & (K.num == 0) & (K.pos != 'NNP') & (K.pos != 'NNPS') & K.term_id.isin(V[V.stop==0].index)

# %% [markdown]
# ### Extract BOW from tokens
#
# To extract a bag-of-words model from our tokens table, we apply a simple `groupby()` operation.

# %%
BOW = K[WORDS].groupby(OHCO[:3]+['term_id'])['term_id'].count()

# %% [markdown]
# ### Convert BOW to DTM

# %%
DTM = BOW.unstack().fillna(0)

# %%
#DTM

# %% [markdown]
# ## Compute Term Frequencies and Weights

# %% [markdown]
# ### Compute TF

# %%
alpha = .000001 # We introduce an arbitrary smoothing value
alpha_sum = alpha * V.shape[0]
TF = DTM.apply(lambda x: (x + alpha) / (x.sum() + alpha_sum), axis=1)

# %% [markdown]
# ### Compute TFIDF

# %%
N_docs = DTM.shape[0]
V['df'] = DTM[DTM > 0].count()
TFIDF = TF * np.log2(N_docs / V[V.stop==0]['df'])

# %% [markdown]
# ### Compute TFTH (Experiment)

# %%
#THM = -(TF * np.log2(TF))
#TFTH = TF.apply(lambda x: x * THM.sum(), 1)

# %% [markdown]
# ### Add stats to V

# %%
#V['tf_sum'] = TF.sum()
V['tf_mean'] = TF.mean()
V['tf_max'] = TF.max()
#V['tfidf_sum'] = TFIDF.sum()
V['tfidf_mean'] = TFIDF.mean()
V['tfidf_max'] = TFIDF.max()
#V['tfth_sum'] = TFTH.sum()
#V['tfth_mean'] = TFTH.mean()
#V['tfth_max'] = TFTH.max()
#V['th_sum'] = THM.sum()
#V['th_mean'] = THM.mean()
#V['th_max'] = THM.max()

# %% [markdown]
# ## Create Docs table

# %%
D = DTM.sum(1).astype('int').to_frame().rename(columns={0:'term_count'})
D['tf'] = D.term_count / D.term_count.sum()
f = open('episodes.txt', 'r') # add episode titles
l = f.readlines()
D['title'] = l
D.title = D.title.str.strip()

# %%
D.title
# Out:
# show_num  seas_num  epis_num
# 0         0         0                                          Pilot (The Office)
#                     1                                               Diversity Day
#                     2                                                 Health Care
#                     3                                                The Alliance
#                     4                                                  Basketball
#                     5                                                    Hot Girl
#           1         0                                                 The Dundies
#                     1                                           Sexual Harassment
#                     2                                             Office Olympics
#                     3                                                    The Fire
#                     4                                                   Halloween
#                     5                                      The Fight (The Office)
#                     6                                                  The Client
#                     7                                          Performance Review
#                     8                                         E-mail Surveillance
#                     9                                             Christmas Party
#                     10                                               Booze Cruise
#                     11                                                 The Injury
#                     12                                                 The Secret
#                     13                                                 The Carpet
#                     14                                             Boys and Girls
#                     15                                            Valentine's Day
#                     16                                            Dwight's Speech
#                     17                             Take Your Daughter to Work Day
#                     18                                         Michael's Birthday
#                     19                                               Drug Testing
#                     20                                        Conflict Resolution
#                     21                                               Casino Night
#           2         0                                              Gay Witch Hunt
#                     1                                              The Convention
#                                                       ...
# 1         5         2                                               Doppelgangers
#                     3                                                  Gin It Up!
#                     4                                                  Filibuster
#                     5                                                 Recall Vote
#                     6                                                    Fluoride
#                     7                                       The Cones of Dunshire
#                     8                                               Second Chunce
#                     9                                              New Beginnings
#                     10                                             Farmers Market
#                     11                                              Ann and Chris
#                     12                                              Anniversaries
#                     13                                                   The Wall
#                     14                                                 New Slogan
#                     15                                          Galentine's Day 2
#                     16                                                       Prom
#                     17                                               Flu Season 2
#                     18                                               One in 8,000
#                     19                                       Moving Up Part 1 & 2
#           6         0                                                        2017
#                     1                                                 Ron & Jammy
#                     2                                      William Henry Harrison
#                     3                                                Leslie & Ron
#                     4                                                   Gryzzlbox
#                     5                                                   Save JJ's
#                     6                                                 Donna & Joe
#                     7                        Ms. Ludgate-Dwyer Goes to Washington
#                     8                                                    Pie-Mary
#                     9           The Johnny Karate Super Awesome Musical Explos...
#                     10                                               Two Funerals
#                     11                                  One Last Ride, Part 1 & 2
# Name: title, Length: 308, dtype: object

# %% [markdown]
# ## Fast Way

# %% [markdown]
# ## Get all doc pairs

# %%
epis_ids = D.index.tolist()
pairs = [(i,j) for i in epis_ids for j in epis_ids if j != i]
P = pd.DataFrame(pairs).reset_index(drop=True).set_index([0,1])
P.index.names = ['doc_x','doc_y']

# %% [markdown]
# ## Compute Euclidean distance

# %%
def euclidean(row):
    D1 = TFIDF.loc[row.name[0]]
    D2 = TFIDF.loc[row.name[1]]
    x = (D1 - D2)**2
    y = x.sum() 
    z = np.sqrt(y)
    return z

# %%
#P['euclidean'] = 0
#P['euclidean'] = P.apply(euclidean, 1)

# %% [markdown]
# ## Compute Cosine similarity

# %%
def cosine(row):
    D1 = TFIDF.loc[row.name[0]]
    D2 = TFIDF.loc[row.name[1]]
    x = D1 * D2
    y = x.sum()
    a = np.sqrt((D1**2).sum())
    b = np.sqrt((D2**2).sum())
    c = a * b
    z = y / c
    return z

# %%
P['cosine'] = 0
P['cosine'] = P.apply(cosine, 1)

# %%
P = P.reset_index() # sqlite can't save tuples, so converted to strings
P[['doc_x', 'doc_y']] = P[['doc_x', 'doc_y']].astype(str)

# %%
#P

# %% [markdown]
# # Create small TFIDF table

# %%
def get_top_terms(vocab, no_stops=True, sort_col='n', k=1000):
    if no_stops:
        V = vocab[vocab.stop == 0]
    else:
        V = vocab
    return V.sort_values(sort_col, ascending=False).head(k)

# %%
proper_nouns = K.loc[(K.pos == 'NNP') & (K.pos == 'NNPS'), 'term_id'].unique()
TOPV = get_top_terms(V.loc[~V.index.isin(proper_nouns)])

# %%
TOPV
# Out:
#            term_str      n         p port_stem  stop     df   tf_mean  \
# term_id
# 120              's  20226  0.019204        's     0  295.0  0.043636
# 14878           n't  10844  0.010296       n't     0  295.0  0.023536
# 82               'm   7537  0.007156        'm     0  293.0  0.016205
# 15549            oh   6326  0.006006        oh     0  308.0  0.013222
# 12522          know   6325  0.006005      know     0  308.0  0.013739
# 115             're   5846  0.005551       're     0  293.0  0.012454
# 13058          like   5254  0.004988      like     0  308.0  0.011387
# 15579          okay   4884  0.004637      okay     0  258.0  0.002832
# 25556          yeah   4642  0.004407      yeah     0  308.0  0.010135
# 18967         right   3994  0.003792     right     0  308.0  0.008669
# 9448            get   3937  0.003738       get     0  308.0  0.008347
# 24946          well   3904  0.003707      well     0  308.0  0.008168
# 9604             go   3621  0.003438        go     0  308.0  0.007374
# 10609           hey   3484  0.003308       hey     0  263.0  0.001665
# 14879            na   3458  0.003283        na     0  284.0  0.007352
# 15618           one   3340  0.003171       one     0  308.0  0.007241
# 22878         think   3243  0.003079     think     0  308.0  0.007054
# 9658           good   3212  0.003050      good     0  308.0  0.006917
# 18198        really   3006  0.002854    realli     0  308.0  0.006554
# 24727          want   2885  0.002739      want     0  305.0  0.006184
# 9632          going   2859  0.002715        go     0  306.0  0.006335
# 25411         would   2826  0.002683     would     0  307.0  0.006114
# 9650            gon   2798  0.002657       gon     0  280.0  0.005876
# 9713            got   2705  0.002568       got     0  308.0  0.005481
# 12947           let   2507  0.002380       let     0  306.0  0.005328
# 25604           yes   2340  0.002222        ye     0  306.0  0.005076
# 79              'll   2336  0.002218       'll     0  292.0  0.004963
# 4633           come   2131  0.002023      come     0  303.0  0.003693
# 23033          time   2052  0.001948      time     0  307.0  0.004377
# 158             've   1981  0.001881       've     0  290.0  0.004198
# ...             ...    ...       ...       ...   ...    ...       ...
# 13735      marriage     74  0.000070   marriag     0   44.0  0.000157
# 877        american     74  0.000070  american     0   42.0  0.000116
# 7102           dumb     74  0.000070      dumb     0   47.0  0.000139
# 17829       putting     73  0.000069       put     0   67.0  0.000160
# 288          accept     73  0.000069    accept     0   51.0  0.000150
# 5705          daddy     73  0.000069     daddi     0   24.0  0.000095
# 22066        summer     73  0.000069    summer     0   35.0  0.000133
# 22367        system     73  0.000069    system     0   50.0  0.000141
# 9468          giant     73  0.000069     giant     0   50.0  0.000147
# 6377           died     73  0.000069       die     0   44.0  0.000169
# 3005         broken     73  0.000069    broken     0   59.0  0.000148
# 19493         santa     73  0.000069     santa     0    1.0  0.000007
# 10654     hilarious     73  0.000069    hilari     0   56.0  0.000156
# 13542          mail     72  0.000068      mail     0   47.0  0.000151
# 15275        normal     72  0.000068    normal     0   53.0  0.000151
# 21538      standing     72  0.000068     stand     0   55.0  0.000150
# 16457         penis     72  0.000068      peni     0   49.0  0.000144
# 12087          jobs     72  0.000068       job     0   54.0  0.000160
# 3812         center     72  0.000068    center     0   30.0  0.000101
# 12950        letter     72  0.000068    letter     0   45.0  0.000144
# 10859        hoping     72  0.000068      hope     0   62.0  0.000152
# 16244          pass     72  0.000068      pass     0   56.0  0.000144
# 12018          jerk     72  0.000068      jerk     0   46.0  0.000144
# 20547        sister     72  0.000068    sister     0   50.0  0.000153
# 19954       senator     71  0.000067     senat     0   20.0  0.000082
# 9720         gotten     71  0.000067    gotten     0   62.0  0.000152
# 23552         truck     71  0.000067     truck     0   32.0  0.000129
# 8005     experience     71  0.000067    experi     0   58.0  0.000150
# 16672         photo     71  0.000067     photo     0   40.0  0.000156
# 8162           fake     71  0.000067      fake     0   51.0  0.000148
#
#            tf_max  tfidf_mean  tfidf_max
# term_id
# 120      0.080778    0.002715   0.005026
# 14878    0.042906    0.001464   0.002669
# 82       0.029869    0.001167   0.002151
# 15549    0.028199    0.000000   0.000000
# 12522    0.029084    0.000000   0.000000
# 115      0.024282    0.000897   0.001749
# 13058    0.026885    0.000000   0.000000
# 15579    0.013628    0.000724   0.003483
# 25556    0.023371    0.000000   0.000000
# 18967    0.021487    0.000000   0.000000
# 9448     0.017527    0.000000   0.000000
# 24946    0.016756    0.000000   0.000000
# 9604     0.021452    0.000000   0.000000
# 10609    0.009700    0.000379   0.002210
# 14879    0.070729    0.000861   0.008278
# 15618    0.019041    0.000000   0.000000
# 22878    0.017107    0.000000   0.000000
# 9658     0.021203    0.000000   0.000000
# 18198    0.014744    0.000000   0.000000
# 24727    0.017543    0.000087   0.000248
# 9632     0.024205    0.000060   0.000227
# 25411    0.015217    0.000029   0.000071
# 9650     0.015625    0.000808   0.002148
# 9713     0.015994    0.000000   0.000000
# 12947    0.015676    0.000050   0.000147
# 25604    0.021091    0.000048   0.000198
# 79       0.012039    0.000382   0.000927
# 4633     0.013223    0.000087   0.000312
# 23033    0.021140    0.000021   0.000099
# 158      0.010618    0.000365   0.000922
# ...           ...         ...        ...
# 13735    0.007133    0.000441   0.020026
# 877      0.001980    0.000334   0.005692
# 7102     0.002714    0.000378   0.007360
# 17829    0.001472    0.000352   0.003239
# 288      0.002609    0.000388   0.006768
# 5705     0.005696    0.000349   0.020970
# 22066    0.006875    0.000418   0.021571
# 22367    0.002746    0.000371   0.007202
# 9468     0.002869    0.000385   0.007525
# 6377     0.009236    0.000475   0.025928
# 3005     0.002059    0.000354   0.004909
# 19493    0.002134    0.000057   0.017639
# 10654    0.002274    0.000383   0.005594
# 13542    0.002311    0.000409   0.006268
# 15275    0.003482    0.000383   0.008840
# 21538    0.003861    0.000373   0.009596
# 16457    0.002377    0.000382   0.006303
# 12087    0.004226    0.000403   0.010616
# 3812     0.004467    0.000338   0.015009
# 12950    0.003187    0.000399   0.008843
# 10859    0.001857    0.000352   0.004294
# 16244    0.002425    0.000354   0.005965
# 12018    0.005814    0.000394   0.015949
# 20547    0.002851    0.000401   0.007478
# 19954    0.003314    0.000324   0.013073
# 9720     0.001553    0.000352   0.003591
# 23552    0.004207    0.000420   0.013742
# 8005     0.002301    0.000362   0.005542
# 16672    0.005232    0.000461   0.015409
# 8162     0.003960    0.000383   0.010274
#
# [1000 rows x 10 columns]

# %% [markdown]
# # Save

# %%
with sqlite3.connect(db_name) as db:
    V.to_sql('vocab', db, if_exists='replace', index=True)
    #K.to_sql('token', db, if_exists='replace', index=True)
    D.to_sql('doc', db, if_exists='replace', index=True)
    P.to_sql('docpair', db, if_exists='replace', index=False)
    #BOW.to_frame().rename(columns={'term_id':'n'}).to_sql('bow', db, if_exists='replace', index=True)
    TFIDF[TOPV.index].stack().to_frame().rename(columns={0:'term_weight'})\
    .to_sql('tfidf_small', db, if_exists='replace', index=True)

# %% [markdown]
# # End
